# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models, regularizers

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0


x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

def build_l2_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu',
                     input_shape=(784,)),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)


test_loss, test_acc = model_l2.evaluate(x_test, y_test)
train_loss,train_acc=model_l2.evaluate(x_train,y_train)
print(f"Test accuracy: {train_acc:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7602 - loss: 0.6914 - val_accuracy: 0.8564 - val_loss: 0.4046
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8550 - loss: 0.4015 - val_accuracy: 0.8648 - val_loss: 0.3717
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8716 - loss: 0.3527 - val_accuracy: 0.8605 - val_loss: 0.3891
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8816 - loss: 0.3270 - val_accuracy: 0.8711 - val_loss: 0.3479
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8862 - loss: 0.3110 - val_accuracy: 0.8791 - val_loss: 0.3381
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8924 - loss: 0.2911 - val_accuracy: 0.8740 - val_loss: 0.3445
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8936 - loss: 0.2819 - val_accuracy: 0.8799 - val_loss: 0.3254
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9010 - loss: 0.2684 - val_accuracy: 0.8803 - val_loss: 0.3369
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9042 - loss: 0.2564 - val_accuracy: 0.8867 - val_loss: 0.3246
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9035 - loss: 0.2497 - val_accuracy: 0.8773 - val_loss: 0.3629
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8649 - loss: 0.3940
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9015 - loss: 0.2626
# Test accuracy: 0.8963
# Test accuracy: 0.8710

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models, regularizers

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize the input data
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# 🔹 FIX: Reshape 28x28 images into 784-length vectors
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define a simple model with L2 regularization
def build_l2_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu',
                     input_shape=(784,),
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)


test_loss, test_acc = model_l2.evaluate(x_test, y_test)
train_loss,train_acc=model_l2.evaluate(x_train,y_train)
print(f"Test accuracy: {train_acc:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7815 - loss: 1.0141 - val_accuracy: 0.8056 - val_loss: 0.7809
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8105 - loss: 0.7180 - val_accuracy: 0.8109 - val_loss: 0.6809
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8167 - loss: 0.6700 - val_accuracy: 0.7628 - val_loss: 0.7669
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8201 - loss: 0.6432 - val_accuracy: 0.8287 - val_loss: 0.6242
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8264 - loss: 0.6194 - val_accuracy: 0.8251 - val_loss: 0.6085
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8321 - loss: 0.6002 - val_accuracy: 0.8324 - val_loss: 0.5998
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8346 - loss: 0.5851 - val_accuracy: 0.8400 - val_loss: 0.5629
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8360 - loss: 0.5757 - val_accuracy: 0.8399 - val_loss: 0.5590
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8371 - loss: 0.5695 - val_accuracy: 0.8328 - val_loss: 0.5758
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8400 - loss: 0.5632 - val_accuracy: 0.8421 - val_loss: 0.5685
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8308 - loss: 0.5861
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8456 - loss: 0.5514
# Test accuracy: 0.8456
# Test accuracy: 0.8308

# %%
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7493 - loss: 0.7172 - val_accuracy: 0.8467 - val_loss: 0.4347
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8565 - loss: 0.4009 - val_accuracy: 0.8663 - val_loss: 0.3766
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8707 - loss: 0.3566 - val_accuracy: 0.8706 - val_loss: 0.3653
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8793 - loss: 0.3329 - val_accuracy: 0.8748 - val_loss: 0.3492
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8894 - loss: 0.2991 - val_accuracy: 0.8810 - val_loss: 0.3284
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8913 - loss: 0.2895 - val_accuracy: 0.8805 - val_loss: 0.3418
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8960 - loss: 0.2795 - val_accuracy: 0.8864 - val_loss: 0.3277
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8970 - loss: 0.2717 - val_accuracy: 0.8820 - val_loss: 0.3296
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9042 - loss: 0.2613 - val_accuracy: 0.8784 - val_loss: 0.3471
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9037 - loss: 0.2537 - val_accuracy: 0.8866 - val_loss: 0.3233
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8775 - loss: 0.3459
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9140 - loss: 0.2270
# Test accuracy: 0.9088
# Test accuracy: 0.8782

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models, regularizers

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize the input data
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# 🔹 FIX: Reshape 28x28 images into 784-length vectors
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define a simple model with L2 regularization
def build_l2_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu',
                     input_shape=(784,),
                     kernel_regularizer=regularizers.l2(0.001)),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(0.001)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)


test_loss, test_acc = model_l2.evaluate(x_test, y_test)
train_loss,train_acc=model_l2.evaluate(x_train,y_train)
print(f"Test accuracy: {train_acc:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7486 - loss: 0.8602 - val_accuracy: 0.8405 - val_loss: 0.5585
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8495 - loss: 0.5319 - val_accuracy: 0.8437 - val_loss: 0.5346
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8572 - loss: 0.4922 - val_accuracy: 0.8491 - val_loss: 0.5085
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8622 - loss: 0.4692 - val_accuracy: 0.8538 - val_loss: 0.4859
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8672 - loss: 0.4520 - val_accuracy: 0.8584 - val_loss: 0.4629
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8667 - loss: 0.4454 - val_accuracy: 0.8727 - val_loss: 0.4415
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8699 - loss: 0.4403 - val_accuracy: 0.8685 - val_loss: 0.4508
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8712 - loss: 0.4287 - val_accuracy: 0.8723 - val_loss: 0.4353
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8743 - loss: 0.4210 - val_accuracy: 0.8697 - val_loss: 0.4417
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8740 - loss: 0.4164 - val_accuracy: 0.8697 - val_loss: 0.4359
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8647 - loss: 0.4548
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8824 - loss: 0.3953
# Test accuracy: 0.8802
# Test accuracy: 0.8602

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models, regularizers

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize the input data
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# 🔹 FIX: Reshape 28x28 images into 784-length vectors
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define a simple model with L2 regularization
def build_l2_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu',
                     input_shape=(784,),
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(0.001)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)


test_loss, test_acc = model_l2.evaluate(x_test, y_test)
train_loss,train_acc=model_l2.evaluate(x_train,y_train)
print(f"Test accuracy: {train_acc:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7426 - loss: 1.1838 - val_accuracy: 0.8204 - val_loss: 0.6463
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8212 - loss: 0.6475 - val_accuracy: 0.8187 - val_loss: 0.6431
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8295 - loss: 0.6076 - val_accuracy: 0.8273 - val_loss: 0.6291
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8344 - loss: 0.5824 - val_accuracy: 0.8403 - val_loss: 0.5666
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8394 - loss: 0.5578 - val_accuracy: 0.8331 - val_loss: 0.5768
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8408 - loss: 0.5459 - val_accuracy: 0.8112 - val_loss: 0.6036
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8431 - loss: 0.5324 - val_accuracy: 0.8372 - val_loss: 0.5547
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8448 - loss: 0.5269 - val_accuracy: 0.8310 - val_loss: 0.5675
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8460 - loss: 0.5190 - val_accuracy: 0.8198 - val_loss: 0.5835
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8479 - loss: 0.5121 - val_accuracy: 0.8423 - val_loss: 0.5246
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8378 - loss: 0.5449
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8511 - loss: 0.4993
# Test accuracy: 0.8493
# Test accuracy: 0.8324

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models, regularizers

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize the input data
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# 🔹 FIX: Reshape 28x28 images into 784-length vectors
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define a simple model with L2 regularization
def build_l2_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu',
                     input_shape=(784,),
                     kernel_regularizer=regularizers.l2(0.001)),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)


test_loss, test_acc = model_l2.evaluate(x_test, y_test)
train_loss,train_acc=model_l2.evaluate(x_train,y_train)
print(f"Test accuracy: {train_acc:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7545 - loss: 1.1308 - val_accuracy: 0.8349 - val_loss: 0.6393
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8406 - loss: 0.6094 - val_accuracy: 0.8290 - val_loss: 0.5824
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8475 - loss: 0.5451 - val_accuracy: 0.8548 - val_loss: 0.5159
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8546 - loss: 0.5196 - val_accuracy: 0.8568 - val_loss: 0.5091
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8567 - loss: 0.4947 - val_accuracy: 0.8438 - val_loss: 0.5273
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8606 - loss: 0.4854 - val_accuracy: 0.8621 - val_loss: 0.4805
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8644 - loss: 0.4734 - val_accuracy: 0.8577 - val_loss: 0.4846
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8662 - loss: 0.4623 - val_accuracy: 0.8587 - val_loss: 0.4790
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8639 - loss: 0.4609 - val_accuracy: 0.8507 - val_loss: 0.5037
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8682 - loss: 0.4485 - val_accuracy: 0.8666 - val_loss: 0.4549
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8597 - loss: 0.4719
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8795 - loss: 0.4242
# Test accuracy: 0.8756
# Test accuracy: 0.8559

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator


(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()


x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)


y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)


datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

datagen.fit(x_train)

def build_l2_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28, 1)),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model_l2.fit(
    datagen.flow(x_train, y_train, batch_size=32),
    epochs=10,
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // 32
)


test_loss, test_acc = model_l2.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 33s 17ms/step - accuracy: 0.7579 - loss: 1.2720 - val_accuracy: 0.9212 - val_loss: 0.6953
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 34s 18ms/step - accuracy: 0.8726 - loss: 0.8151 - val_accuracy: 0.9334 - val_loss: 0.5876
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 17ms/step - accuracy: 0.8880 - loss: 0.7157 - val_accuracy: 0.9446 - val_loss: 0.5240
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8947 - loss: 0.6657 - val_accuracy: 0.9429 - val_loss: 0.4927
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8979 - loss: 0.6323 - val_accuracy: 0.9444 - val_loss: 0.4746
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 17ms/step - accuracy: 0.9016 - loss: 0.6045 - val_accuracy: 0.9332 - val_loss: 0.4842
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.9039 - loss: 0.5852 - val_accuracy: 0.9514 - val_loss: 0.4317
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 17ms/step - accuracy: 0.9059 - loss: 0.5727 - val_accuracy: 0.9474 - val_loss: 0.4261
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.9067 - loss: 0.5606 - val_accuracy: 0.9338 - val_loss: 0.4521
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 17ms/step - accuracy: 0.9078 - loss: 0.5499 - val_accuracy: 0.9475 - val_loss: 0.4083
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9475 - loss: 0.4083
# Test accuracy: 0.9475

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0


x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
def build_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu', input_shape=(784,)),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

model = build_model()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


earlystop = EarlyStopping(
    monitor='val_accuracy',
    patience=3,
    restore_best_weights=True
)

epochs = 20
batch_size = 256

history = model.fit(
    x_train,
    y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=0.2,
    callbacks=[earlystop]
)


test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7618 - loss: 0.7136 - val_accuracy: 0.8349 - val_loss: 0.4827
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8439 - loss: 0.4436 - val_accuracy: 0.8537 - val_loss: 0.4183
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8586 - loss: 0.3989 - val_accuracy: 0.8472 - val_loss: 0.4182
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8673 - loss: 0.3706 - val_accuracy: 0.8621 - val_loss: 0.3875
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8732 - loss: 0.3526 - val_accuracy: 0.8657 - val_loss: 0.3778
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8781 - loss: 0.3365 - val_accuracy: 0.8676 - val_loss: 0.3642
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8825 - loss: 0.3243 - val_accuracy: 0.8740 - val_loss: 0.3529
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8850 - loss: 0.3134 - val_accuracy: 0.8767 - val_loss: 0.3510
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8903 - loss: 0.2997 - val_accuracy: 0.8725 - val_loss: 0.3454
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8929 - loss: 0.2926 - val_accuracy: 0.8817 - val_loss: 0.3361
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8956 - loss: 0.2851 - val_accuracy: 0.8782 - val_loss: 0.3386
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8978 - loss: 0.2760 - val_accuracy: 0.8771 - val_loss: 0.3486
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9005 - loss: 0.2703 - val_accuracy: 0.8853 - val_loss: 0.3324
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9028 - loss: 0.2643 - val_accuracy: 0.8833 - val_loss: 0.3262
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9045 - loss: 0.2593 - val_accuracy: 0.8837 - val_loss: 0.3296
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.2513 - val_accuracy: 0.8848 - val_loss: 0.3273
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8753 - loss: 0.3625
# Test accuracy: 0.8753

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)


def build_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu', input_shape=(784,)),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(10, activation='softmax')
    ])
    return model

model = build_model()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

epochs = 20
batch_size = 256

history = model.fit(
    x_train,
    y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=0.2
)

test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6486 - loss: 0.9916 - val_accuracy: 0.8120 - val_loss: 0.5322
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7893 - loss: 0.5942 - val_accuracy: 0.8369 - val_loss: 0.4546
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8214 - loss: 0.5165 - val_accuracy: 0.8503 - val_loss: 0.4122
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8293 - loss: 0.4854 - val_accuracy: 0.8550 - val_loss: 0.3947
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8372 - loss: 0.4586 - val_accuracy: 0.8587 - val_loss: 0.3877
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8444 - loss: 0.4399 - val_accuracy: 0.8627 - val_loss: 0.3790
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8463 - loss: 0.4289 - val_accuracy: 0.8652 - val_loss: 0.3638
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8515 - loss: 0.4177 - val_accuracy: 0.8676 - val_loss: 0.3640
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8551 - loss: 0.4052 - val_accuracy: 0.8726 - val_loss: 0.3542
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8583 - loss: 0.3989 - val_accuracy: 0.8714 - val_loss: 0.3548
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8612 - loss: 0.3880 - val_accuracy: 0.8719 - val_loss: 0.3524
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8621 - loss: 0.3859 - val_accuracy: 0.8723 - val_loss: 0.3477
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8616 - loss: 0.3783 - val_accuracy: 0.8708 - val_loss: 0.3477
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8650 - loss: 0.3727 - val_accuracy: 0.8716 - val_loss: 0.3483
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8661 - loss: 0.3661 - val_accuracy: 0.8730 - val_loss: 0.3448
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8701 - loss: 0.3631 - val_accuracy: 0.8771 - val_loss: 0.3444
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8699 - loss: 0.3576 - val_accuracy: 0.8783 - val_loss: 0.3375
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8695 - loss: 0.3562 - val_accuracy: 0.8767 - val_loss: 0.3398
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8704 - loss: 0.3548 - val_accuracy: 0.8767 - val_loss: 0.3366
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8716 - loss: 0.3508 - val_accuracy: 0.8792 - val_loss: 0.3370
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8767 - loss: 0.3556
# Test accuracy: 0.8767

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras import layers, models


(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

noise_factor = 0.2
x_train_noisy = x_train + noise_factor * np.random.normal(
    loc=0.0, scale=1.0, size=x_train.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)


noise_ratio = 0.1
num_samples = int(noise_ratio * y_train.shape[0])

random_indices = np.random.choice(y_train.shape[0], num_samples, replace=False)

for idx in random_indices:
    random_label = np.random.randint(0, 10)
    y_train[idx] = to_categorical(random_label, 10)


def build_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu', input_shape=(784,)),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

model = build_model()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model.fit(
    x_train_noisy,
    y_train,
    epochs=20,
    batch_size=256,
    validation_split=0.2
)


test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6610 - loss: 1.1621 - val_accuracy: 0.7317 - val_loss: 0.9814
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7421 - loss: 0.9510 - val_accuracy: 0.7433 - val_loss: 0.9490
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7573 - loss: 0.9078 - val_accuracy: 0.7553 - val_loss: 0.9175
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7669 - loss: 0.8761 - val_accuracy: 0.7617 - val_loss: 0.8966
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7739 - loss: 0.8489 - val_accuracy: 0.7613 - val_loss: 0.8923
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7810 - loss: 0.8272 - val_accuracy: 0.7657 - val_loss: 0.8788
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7865 - loss: 0.8106 - val_accuracy: 0.7628 - val_loss: 0.8961
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7905 - loss: 0.7946 - val_accuracy: 0.7688 - val_loss: 0.8719
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7937 - loss: 0.7799 - val_accuracy: 0.7688 - val_loss: 0.8845
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7958 - loss: 0.7664 - val_accuracy: 0.7732 - val_loss: 0.8651
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8019 - loss: 0.7509 - val_accuracy: 0.7719 - val_loss: 0.8710
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7999 - loss: 0.7454 - val_accuracy: 0.7742 - val_loss: 0.8719
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8054 - loss: 0.7295 - val_accuracy: 0.7687 - val_loss: 0.8742
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8083 - loss: 0.7182 - val_accuracy: 0.7689 - val_loss: 0.8757
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8097 - loss: 0.7073 - val_accuracy: 0.7687 - val_loss: 0.8800
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8122 - loss: 0.6944 - val_accuracy: 0.7714 - val_loss: 0.8868
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8147 - loss: 0.6875 - val_accuracy: 0.7688 - val_loss: 0.8913
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8189 - loss: 0.6724 - val_accuracy: 0.7569 - val_loss: 0.9235
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8189 - loss: 0.6653 - val_accuracy: 0.7681 - val_loss: 0.9043
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8227 - loss: 0.6527 - val_accuracy: 0.7649 - val_loss: 0.9107
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8441 - loss: 0.6376
# Test accuracy: 0.8441

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical


(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()


x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
shared_dense = Dense(64, activation='relu')
input1 = Input(shape=(784,))
input2 = Input(shape=(784,))

encoded1 = shared_dense(input1)
encoded2 = shared_dense(input2)
merged = Concatenate()([encoded1, encoded2])
output = Dense(10, activation='softmax')(merged)

model = Model(inputs=[input1, input2], outputs=output)

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit([x_train, x_train], y_train,
          epochs=5,
          batch_size=256,
          validation_split=0.2)

test_loss, test_acc = model.evaluate([x_test, x_test], y_test)
print("Test accuracy (Parameter Sharing):", test_acc)
# Out:
# Epoch 1/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7670 - loss: 0.6820 - val_accuracy: 0.8296 - val_loss: 0.4926
# Epoch 2/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8418 - loss: 0.4566 - val_accuracy: 0.8413 - val_loss: 0.4473
# Epoch 3/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8576 - loss: 0.4088 - val_accuracy: 0.8465 - val_loss: 0.4432
# Epoch 4/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8654 - loss: 0.3835 - val_accuracy: 0.8608 - val_loss: 0.3953
# Epoch 5/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8713 - loss: 0.3643 - val_accuracy: 0.8596 - val_loss: 0.3927
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8511 - loss: 0.4145
# Test accuracy (Parameter Sharing): 0.8511000275611877

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models


(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()


x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0


x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)


model1 = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(784,)),
    layers.Dense(10, activation='softmax')
])

model1.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

model1.fit(x_train, y_train_cat,
           epochs=5, batch_size=256, verbose=0)


model2 = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dense(10, activation='softmax')
])

model2.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

model2.fit(x_train, y_train_cat,
           epochs=5, batch_size=256, verbose=0)


model3 = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model3.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

model3.fit(x_train, y_train_cat,
           epochs=5, batch_size=256, verbose=0)


print("Model 1 Accuracy:", model1.evaluate(x_test, y_test_cat, verbose=0)[1])
print("Model 2 Accuracy:", model2.evaluate(x_test, y_test_cat, verbose=0)[1])
print("Model 3 Accuracy:", model3.evaluate(x_test, y_test_cat, verbose=0)[1])

pred1 = model1.predict(x_test)
pred2 = model2.predict(x_test)
pred3 = model3.predict(x_test)


ensemble_pred = (pred1 + pred2 + pred3) / 3

ensemble_classes = np.argmax(ensemble_pred, axis=1)


ensemble_accuracy = np.mean(ensemble_classes == y_test)

print("Ensemble Accuracy:", ensemble_accuracy)
# Out:
# Model 1 Accuracy: 0.8557000160217285
# Model 2 Accuracy: 0.8695999979972839
# Model 3 Accuracy: 0.8654000163078308
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Ensemble Accuracy: 0.871
